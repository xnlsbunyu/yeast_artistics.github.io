# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from matplotlib.font_manager import FontProperties

# %%
fig, ax = plt.subplots()
grid = np.mgrid[0:1:12j, 0.2:0.8:8j].reshape(2, -1).T
patches = []
for i in range(len(grid)):
    circle = mpatches.Circle(grid[i], 0.042, ec="k")
    patches.append(circle)
fancybox = mpatches.FancyBboxPatch(
    [-0.05,0.15], 1.1, 0.69, boxstyle=mpatches.BoxStyle("Round", pad=0.01), fc="none")
colors = np.random.rand(len(patches))
collection = PatchCollection(patches, cmap=plt.cm.tab20, alpha =0.6)
collection.set_array(np.array(colors))
ax.add_collection(collection)
ax.add_patch(fancybox)
plt.axis("equal")
plt.axis("off")
# plt.tick_params(axis="both", which="both", bottom=False, top=False, left=False, labelbottom=False, labelleft=False)
plt.tight_layout()
plt.savefig("96_well_plate.png",dpi=200, bbox_inches="tight")
plt.show()
